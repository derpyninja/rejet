# %% [markdown]
# # Compute transition numbers for green, brown and neutral occupations without education etc. constraints
# Felix Zaussinger | 20.08.2021
#
# ## Core Analysis Goal(s)
# 1. Map transition pathways based on new G/B/N classification and other proxies
#
# ## Key Insight(s)
# 1.

# %%
import os
import sys
import logging
from pathlib import Path

import numpy as np
import scipy as sp
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import seaborn as sns
sns.set_context("paper")
#sns.set(rc={'figure.figsize': (16, 9.)})
sns.set_style("ticks")

import pandas as pd
pd.set_option("display.max_rows", 120)
pd.set_option("display.max_columns", 120)

from tqdm import tqdm
from scipy.spatial.distance import pdist, squareform

logging.basicConfig(level=logging.INFO, stream=sys.stdout)

# %% [markdown]
# Define directory structure

# %%
# project directory
abspath = os.path.abspath('')
project_dir = str(Path(abspath).parents[0])

# sub-directories
data_raw = os.path.join(project_dir, "data", "raw")
data_interim = os.path.join(project_dir, "data", "interim")
data_processed = os.path.join(project_dir, "data", "processed")
figure_dir = os.path.join(project_dir, "reports", "figures")

# %% [markdown]
# ESCO data set components

# %%
occ = pd.read_csv(os.path.join(data_raw, "esco", "v1.0.3", "occupations_en.csv"))
skill_groups = pd.read_csv(os.path.join(data_raw, "esco", "v1.0.3", "skillGroups_en.csv"))
skills = pd.read_csv(os.path.join(data_raw, "esco", "v1.0.3", "skills_en.csv"))
occ_skills_mapping = pd.read_csv(os.path.join(data_raw, "esco", "v1.0.3", "occupationSkillRelations.csv"))

# %%
df_metadata = pd.read_csv(
    os.path.join(data_interim, "ESCO_ONET_METADATA_gbn.csv"),
    index_col=0
)

#df_metadata = df_metadata.set_index("id")
df_metadata
#df_metadata.greenness_vona_2018_v2 = df_metadata.greenness_vona_2018_v2.fillna(0)

# convert job zone to categorical var
#df_metadata.job_zone = pd.Categorical(df_metadata.job_zone, ordered=True)
#df_metadata.isco_level_1 = pd.Categorical(df_metadata.isco_level_1, ordered=False)
#df_metadata.isco_level_2 = pd.Categorical(df_metadata.isco_level_2, ordered=False)
# Out:
#         id                                        concept_uri  \
# 0        0  http://data.europa.eu/esco/occupation/00030d09...
# 1        1  http://data.europa.eu/esco/occupation/000e93a3...
# 2        2  http://data.europa.eu/esco/occupation/0019b951...
# 3        3  http://data.europa.eu/esco/occupation/0022f466...
# 4        4  http://data.europa.eu/esco/occupation/002da35b...
# ...    ...                                                ...
# 2916  2937  http://data.europa.eu/esco/occupation/ff656b3a...
# 2917  2938  http://data.europa.eu/esco/occupation/ff8d4065...
# 2918  2939  http://data.europa.eu/esco/occupation/ffa4dd5d...
# 2919  2940  http://data.europa.eu/esco/occupation/ffade2f4...
# 2920  2941  http://data.europa.eu/esco/occupation/ffc292f1...
#
#                            preferred_label  isco_level_4   onet_code  \
# 0                       technical director          2166  27-1011.00
# 1           metal drawing machine operator          8121  51-4021.00
# 2               precision device inspector          7543  51-9061.00
# 3            air traffic safety technician          3155  17-3023.01
# 4              hospitality revenue manager          2431  13-1161.00
# ...                                    ...           ...         ...
# 2916                           demographer          2120  15-2041.00
# 2917                       sorter labourer          9612  51-9199.01
# 2918                    armoured car guard          5414  33-9032.00
# 2919  civil service administrative officer          2422  11-3011.00
# 2920               motor vehicle assembler          8211  51-2031.00
#
#                                         onet_occupation  isco_level_1  \
# 0                                         art directors             2
# 1     extruding and drawing machine setters, operato...             8
# 2     inspectors, testers, sorters, samplers, and we...             7
# 3                   electronics engineering technicians             3
# 4     market research analysts and marketing special...             2
# ...                                                 ...           ...
# 2916                                      statisticians             2
# 2917                  recycling and reclamation workers             9
# 2918                                    security guards             5
# 2919                   administrative services managers             2
# 2920                engine and other machine assemblers             8
#
#       isco_level_2  isco_level_3        occupation_type  n_new_green_tasks  \
# 0               21           216              Non Green                NaN
# 1               81           812              Non Green                NaN
# 2               75           754  Green Enhanced Skills                2.0
# 3               31           315              Non Green                NaN
# 4               24           243              Non Green                NaN
# ...            ...           ...                    ...                ...
# 2916            21           212              Non Green                NaN
# 2917            96           961          New Green N&E               18.0
# 2918            54           541              Non Green                NaN
# 2919            24           242              Non Green                NaN
# 2920            82           821              Non Green                NaN
#
#       n_existing_green_tasks  n_non_green_tasks  greenness_vona_2018  \
# 0                        NaN                NaN                  NaN
# 1                        NaN                NaN                  NaN
# 2                        0.0               30.0             0.066667
# 3                        NaN                NaN                  NaN
# 4                        NaN                NaN                  NaN
# ...                      ...                ...                  ...
# 2916                     NaN                NaN                  NaN
# 2917                     0.0                0.0             1.000000
# 2918                     NaN                NaN                  NaN
# 2919                     NaN                NaN                  NaN
# 2920                     NaN                NaN                  NaN
#
#       greenness_vona_2018_v2  total_paid_hours  annual_earnings  \
# 0                     0.0000         36.670202     37555.308176
# 1                     0.0000         39.904110     22031.963636
# 2                     0.0625         38.709386     22430.367647
# 3                     0.0000         42.036716     32754.000000
# 4                     0.0000         36.354676     38839.816377
# ...                      ...               ...              ...
# 2916                  0.0000         35.494487     36135.290249
# 2917                  1.0000         39.443972     21357.054545
# 2918                  0.0000         37.021429     24315.540984
# 2919                  0.0000         35.240566     33292.986333
# 2920                  0.0000         41.487179     29879.320665
#
#       employment_share  employment_count  job_zone  education_level  \
# 0                  NaN               NaN       4.0           6.2477
# 1             0.000020             645.0       2.0           2.1163
# 2                  NaN               NaN       2.0           2.5397
# 3             0.000087            2797.0       3.0           4.3848
# 4             0.000648           20834.0       4.0           6.8261
# ...                ...               ...       ...              ...
# 2916          0.000286            9184.0       5.0           8.3000
# 2917          0.000417           13414.0       2.0           3.1532
# 2918               NaN               NaN       2.0           2.2215
# 2919          0.001128           36261.0       3.0           3.9636
# 2920          0.000167            5356.0       2.0           2.5437
#
#       related_work_experience  on_the_job_training skill_level_ilo  \
# 0                      8.0309               4.3843               H
# 1                      2.4383               3.6486               M
# 2                      4.8863               4.0288               M
# 3                      5.4808               4.0782               H
# 4                      6.3481               3.8265               H
# ...                       ...                  ...             ...
# 2916                   5.5000               4.6000               H
# 2917                   3.3559               2.8314               L
# 2918                   3.2642               2.0230               M
# 2919                   6.9711               3.4248               H
# 2920                   5.1766               4.4145               M
#
#       new_jobs_absorbing_ilo_2030_es  new_jobs_net_ilo_2030_es  \
# 0                           500000.0                  263000.0
# 1                           339000.0                  712000.0
# 2                            48000.0                  316000.0
# 3                           748000.0                  528000.0
# 4                           218000.0                  147000.0
# ...                              ...                       ...
# 2916                        500000.0                  263000.0
# 2917                        153000.0                  305000.0
# 2918                        141000.0                  179000.0
# 2919                        218000.0                  147000.0
# 2920                         15000.0                  565000.0
#
#       jobs_lost_net_ilo_2030_es  jobs_lost_reallocated_ilo_2030_es  \
# 0                     -253000.0                          -500000.0
# 1                      -34000.0                          -339000.0
# 2                        -500.0                           -48000.0
# 3                     -206000.0                          -748000.0
# 4                      -75000.0                          -218000.0
# ...                         ...                                ...
# 2916                  -253000.0                          -500000.0
# 2917                   -17000.0                          -153000.0
# 2918                   -27000.0                          -141000.0
# 2919                   -75000.0                          -218000.0
# 2920                     -500.0                           -15000.0
#
#       net_change_ilo_2030_es  new_jobs_absorbing_ilo_2030_ce  \
# 0                    10000.0                       1379000.0
# 1                   678000.0                       2913000.0
# 2                   315500.0                       1315000.0
# 3                   322000.0                       3042000.0
# 4                    72000.0                        823000.0
# ...                      ...                             ...
# 2916                 10000.0                       1379000.0
# 2917                288000.0                        860000.0
# 2918                152000.0                        744000.0
# 2919                 72000.0                        823000.0
# 2920                564500.0                        224000.0
#
#       new_jobs_net_ilo_2030_ce  jobs_lost_net_ilo_2030_ce  \
# 0                    1274000.0                  -397000.0
# 1                        500.0                 -5589000.0
# 2                     408000.0                  -440000.0
# 3                    1225000.0                  -965000.0
# 4                     837000.0                   -53000.0
# ...                        ...                        ...
# 2916                 1274000.0                  -397000.0
# 2917                 1152000.0                  -111000.0
# 2918                  579000.0                  -497000.0
# 2919                  837000.0                   -53000.0
# 2920                   14000.0                  -367000.0
#
#       jobs_lost_reallocated_ilo_2030_ce  net_change_ilo_2030_ce  is_brown  \
# 0                            -1379000.0                877000.0     False
# 1                            -2913000.0              -5588500.0      True
# 2                            -1315000.0                -32000.0     False
# 3                            -3042000.0                260000.0     False
# 4                             -823000.0                784000.0     False
# ...                                 ...                     ...       ...
# 2916                         -1379000.0                877000.0     False
# 2917                          -860000.0               1041000.0     False
# 2918                          -744000.0                 82000.0     False
# 2919                          -823000.0                784000.0     False
# 2920                          -224000.0               -353000.0     False
#
#       is_green  is_neutral
# 0        False        True
# 1        False       False
# 2         True       False
# 3        False        True
# 4        False        True
# ...        ...         ...
# 2916     False        True
# 2917      True       False
# 2918     False        True
# 2919     False        True
# 2920     False        True
#
# [2921 rows x 37 columns]

# %%
# nesta report
sim_kanders = np.load(
    os.path.join(data_raw, "mcc_data", "processed", "sim_matrices", "OccupationSimilarity_Combined_no_military.npy")
)

np.fill_diagonal(sim_kanders, 0)

# %% [markdown]
# ## Determine closest matches based on skill similiarity

# %%
# source: https://github.com/nestauk/mapping-career-causeways/blob/main/mapping_career_causeways/compare_nodes_utils.py
def find_closest(i, similarity_matrix, df):
    """
    Method for reporting the closest neighbours to a node i given a similarity matrix;
    useful during exploratory data analysis.
    Parameters
    ----------
    i (int OR None):
        Determines for which node where are assessing the closest neighbours;
        if i==None, a random node is chosen.
    similarity_matrix (numpy.ndarray):
        Similarity matrix determining the closeness between each pair of nodes.
    df (pandas.DataFrame):
        Dataframe to be used for reporting the closest neighbours; must have then
        same number of rows as the similarity matrix
    Returns
    -------
    df (pandas.DataFrame):
        The same input dataframe with an added column for similarity values
        between node i and the rest of the nodes, ordered in a descending order
        of similarity.
    """
    if type(i) == type(None):
        i = np.random.randint(similarity_matrix.shape[0])

    most_similar = np.flip(np.argsort(similarity_matrix[i,:]))
    similarity = np.flip(np.sort(similarity_matrix[i,:]))

    df = df.copy().loc[most_similar]
    df['similarity'] = similarity
    return df

# %% [markdown]
# ## Iterate over all occupations and identify transition options

# %%
VIABLE = 0.3
HIGHLY_VIABLE = 0.4
EARNINGS_RATIO = 0.75
JOB_ZONE_DELTA = 5  # only change needed for unconstrained transition numbers

# %%
transition_numbers_all = {}
df_occ = pd.DataFrame(df_metadata.concept_uri.values, columns=["conceptUri"])

# iterate over mining occupations
for i in tqdm(df_metadata.index.values):

    # find closest occupations
    sim_ranking = find_closest(
        i=i,
        similarity_matrix=sim_kanders,
        df=df_occ
    )

    # print source occupation
    source_occ = df_metadata.iloc[i, :]
    #print("Source occupation: {}".format(source_occ.preferred_label))

    # merge metadata
    result = pd.merge(
        sim_ranking,
        df_metadata[[
            "concept_uri",
            "preferred_label",
            "annual_earnings",
            "is_brown",
            "is_green",
            "is_neutral",
            "job_zone"
        ]],
        left_on="conceptUri",
        right_on="concept_uri",
        how="left"
    ).drop(columns=["concept_uri"], axis=1)

    # add transitions metadata
    result["job_zone_delta"] = np.abs(source_occ.job_zone - result.job_zone)
    result["earnings_ratio"] = result.annual_earnings / source_occ.annual_earnings

    result["is_viable"] = (result.similarity >= VIABLE) & (result.job_zone_delta <= JOB_ZONE_DELTA)
    result["is_highly_viable"] = (result.similarity >= HIGHLY_VIABLE)  & (result.job_zone_delta <= JOB_ZONE_DELTA)
    result["is_desirable"] = result.is_viable & (result.earnings_ratio >= EARNINGS_RATIO)
    result["is_highly_desirable"] = result.is_highly_viable & (result.earnings_ratio >= EARNINGS_RATIO)
    #result["is_green"] = result.greenness_vona_2018_v2 > 0
    #result["is_neutral"] = (result.greenness_vona_2018_v2 == 0) & (result.is_brown == False)

    # viable transitions by gbn
    result["is_viable_brown"] = result.is_viable & (result.is_brown == True)
    result["is_viable_neutral"] = result.is_viable & (result.is_neutral == True)
    result["is_viable_green"] = result.is_viable & (result.is_green == True)

    # highly viable transitions by gbn
    result["is_highly_viable_brown"] = result.is_highly_viable & (result.is_brown == True)
    result["is_highly_viable_neutral"] = result.is_highly_viable & (result.is_neutral == True)
    result["is_highly_viable_green"] = result.is_highly_viable & (result.is_green == True)

    # desirable transitions by gbn
    result["is_desirable_brown"] = result.is_desirable & (result.is_brown == True)
    result["is_desirable_neutral"] = result.is_desirable & (result.is_neutral == True)
    result["is_desirable_green"] = result.is_desirable & (result.is_green == True)

    # highly desirable transitions by gbn
    result["is_highly_desirable_brown"] = result.is_highly_desirable & (result.is_brown == True)
    result["is_highly_desirable_neutral"] = result.is_highly_desirable & (result.is_neutral == True)
    result["is_highly_desirable_green"] = result.is_highly_desirable & (result.is_green == True)

    # subset to viable transitions
    result_subset = result[result.is_viable == True]

    # subset to boolean cols
    boolean_cols = [
        'is_viable', 'is_highly_viable', 'is_desirable', 'is_highly_desirable',
        'is_viable_brown', 'is_viable_neutral', 'is_viable_green',
        'is_highly_viable_brown', 'is_highly_viable_neutral', 'is_highly_viable_green',
        'is_desirable_brown', 'is_desirable_neutral', 'is_desirable_green',
        'is_highly_desirable_brown', 'is_highly_desirable_neutral', 'is_highly_desirable_green'
    ]

    # subset to viable transitions only
    result_subset_bools = result_subset[boolean_cols]

    # count True's per boolean column
    s_sum = result_subset_bools.sum()

    transition_numbers_all[i] = s_sum
# Out:
# 100%|██████████| 2921/2921 [00:57<00:00, 50.77it/s]

# %%
# to df
cols_merge = ["preferred_label", "isco_level_1"] #, "annual_earnings", "education_level", "related_work_experience", "on_the_job_training"]
df_transition_numbers_all = pd.DataFrame.from_dict(transition_numbers_all).transpose()
df_transition_numbers_all_labelled = pd.concat(
    [df_metadata[cols_merge], df_transition_numbers_all], axis=1
)

# %%
# rename binary identifier column to avoid confusion with transition number col
#df_metadata = df_metadata.rename(columns={"is_brown": "brown"})

# delineate "neutral" occupations as those that are non-green and non-mining
#df_metadata["neutral"] = (df_metadata.greenness_vona_2018_v2 == 0) & (df_metadata.brown == False)

# bool for green occupations
#df_metadata["green"] = (df_metadata.greenness_vona_2018_v2 > 0)

# %%
# merge transition numbers to all the other metadata, export csv
df_metadata_transitions = pd.concat(
    [df_metadata, df_transition_numbers_all], axis=1
)

df_metadata_transitions.to_csv(
    os.path.join(data_interim, "esco_onet_metadata_transition_numbers_v2.csv")
)

# %% [markdown]
# #### Scatterplot: growth delta vs transition numbers

# %%
sns.regplot(
    data=df_metadata_transitions,
    x="is_viable",
    y="net_change_ilo_2030_es"
)
# Out:
# <AxesSubplot:xlabel='is_viable', ylabel='net_change_ilo_2030_es'>

# %% [markdown]
# ## Visualise transition numbers for all occupations

# %%
# boxplots of transition numbers by isco lvl 1 groups
isco_lvl1_mapping = {
    1: "Managers",
    2: "Professionals",
    3: "Technicians and associate professionals",
    4: "Clerical support workers",
    5: "Service and sales workers",
    6: "Skilled agricultural, forestry and fishery workers",
    7: "Craft and related trades workers",
    8: "Plant and machine operators and assemblers",
    9: "Elementary occupations"
}

df_transition_numbers_all_labelled.boxplot(
    column=["is_viable", "is_highly_viable", "is_desirable", "is_highly_desirable"],
    by="isco_level_1",
    layout=(2,2),
    rot=90
)

plt.xticks(np.arange(1,10), list(isco_lvl1_mapping.values()))

plt.tight_layout()
# Out:
# <ipython-input-13-94f1c8a63161>:23: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   plt.tight_layout()

# %%
df_transition_numbers_all_labelled
# Out:
#                            preferred_label  isco_level_1  is_viable  \
# 0                       technical director             2         29
# 1           metal drawing machine operator             8        175
# 2               precision device inspector             7        329
# 3            air traffic safety technician             3         82
# 4              hospitality revenue manager             2        296
# ...                                    ...           ...        ...
# 2916                           demographer             2        134
# 2917                       sorter labourer             9         12
# 2918                    armoured car guard             5         53
# 2919  civil service administrative officer             2         81
# 2920               motor vehicle assembler             8        152
#
#       is_highly_viable  is_desirable  is_highly_desirable  is_viable_brown  \
# 0                    3            21                    1                0
# 1                  128           175                  128               96
# 2                   95           328                   95              115
# 3                   13            75                   13                2
# 4                   28           232                   25                3
# ...                ...           ...                  ...              ...
# 2916                40           122                   36                3
# 2917                 2            11                    2                2
# 2918                16            50                   15                1
# 2919                 3            56                    3                0
# 2920                37           143                   37               31
#
#       is_viable_neutral  is_viable_green  is_highly_viable_brown  \
# 0                    27                2                       0
# 1                    66               13                      75
# 2                   136               78                      15
# 3                    61               19                       0
# 4                   206               87                       0
# ...                 ...              ...                     ...
# 2916                 84               47                       1
# 2917                  6                4                       0
# 2918                 50                2                       0
# 2919                 72                9                       0
# 2920                 97               24                       5
#
#       is_highly_viable_neutral  is_highly_viable_green  is_desirable_brown  \
# 0                            3                       0                   0
# 1                           49                       4                  96
# 2                           52                      28                 115
# 3                           13                       0                   2
# 4                           16                      12                   3
# ...                        ...                     ...                 ...
# 2916                        27                      12                   3
# 2917                         0                       2                   1
# 2918                        16                       0                   1
# 2919                         3                       0                   0
# 2920                        25                       7                  24
#
#       is_desirable_neutral  is_desirable_green  is_highly_desirable_brown  \
# 0                       19                   2                          0
# 1                       66                  13                         75
# 2                      136                  77                         15
# 3                       57                  16                          0
# 4                      145                  84                          0
# ...                    ...                 ...                        ...
# 2916                    75                  44                          1
# 2917                     6                   4                          0
# 2918                    47                   2                          0
# 2919                    47                   9                          0
# 2920                    95                  24                          5
#
#       is_highly_desirable_neutral  is_highly_desirable_green
# 0                               1                          0
# 1                              49                          4
# 2                              52                         28
# 3                              13                          0
# 4                              15                         10
# ...                           ...                        ...
# 2916                           26                          9
# 2917                            0                          2
# 2918                           15                          0
# 2919                            3                          0
# 2920                           25                          7
#
# [2921 rows x 18 columns]

# %%
# Visualise differences in transition options to neutral, green and mining
# occupations

value_vars = list(filter(None, [col_label if "is_" in col_label else None for col_label in df_transition_numbers_all_labelled.columns]))
df_ntrans_long = df_transition_numbers_all_labelled.melt(
    value_vars=value_vars,
    id_vars=['preferred_label', 'isco_level_1'],
    var_name="Target"
)

# %%
# viable
df_ntrans_long_is_viable = df_ntrans_long.query("Target == 'is_viable_brown' or Target == 'is_viable_neutral' or Target == 'is_viable_green'")
replace_dict = {"Target": {"is_viable_green": "green", "is_viable_neutral": "neutral", "is_viable_brown": "brown"}}

ax = sns.boxplot(
    y="isco_level_1",
    x="value",
    hue="Target",
    hue_order=["neutral", "green", "brown"],
    palette=["grey", "lightgreen", "orange"],
    saturation=0.6,
    fliersize=1,
    orient="h",
    data=df_ntrans_long_is_viable.replace(replace_dict)
)

ax.set_xlim(0)
plt.legend(loc="lower right")
#ax.set_title("Composition of viable transitions by ISCO-08 1-digit group")
ax.set_xlabel("Number of viable transitions [-]")
ax.set_ylabel(None)
plt.yticks(np.arange(0,9), list(isco_lvl1_mapping.values()), rotation='horizontal')
plt.tight_layout()
sns.despine()

# %% [markdown]
# #### Experiment: try to normalise by counts of occupations per category

# %%
gbn_per_mg = df_metadata_transitions[["isco_level_1", "is_green", "is_brown", "is_neutral"]].groupby("isco_level_1").sum()
gbn_per_mg_long = gbn_per_mg.reset_index().melt(id_vars=["isco_level_1"], value_vars=["is_green", "is_brown", "is_neutral"], value_name="base_number")
gbn_per_mg_long = gbn_per_mg_long.replace({"variable": {"is_green": "green", "is_neutral": "neutral", "is_brown": "brown"}})

# %%
df_ntrans_long_is_viable_norm = pd.merge(
    df_ntrans_long_is_viable.replace(replace_dict),
    gbn_per_mg_long,
    left_on=["isco_level_1", "Target"],
    right_on=["isco_level_1", "variable"],
    how="left"
)

df_ntrans_long_is_viable_norm["quotient"] = df_ntrans_long_is_viable_norm["value"] / df_ntrans_long_is_viable_norm["base_number"]
df_ntrans_long_is_viable_norm
# Out:
#                            preferred_label  isco_level_1 Target  value  \
# 0                       technical director             2  brown      0
# 1           metal drawing machine operator             8  brown     96
# 2               precision device inspector             7  brown    115
# 3            air traffic safety technician             3  brown      2
# 4              hospitality revenue manager             2  brown      3
# ...                                    ...           ...    ...    ...
# 8758                           demographer             2  green     47
# 8759                       sorter labourer             9  green      4
# 8760                    armoured car guard             5  green      2
# 8761  civil service administrative officer             2  green      9
# 8762               motor vehicle assembler             8  green     24
#
#      variable  base_number  quotient
# 0       brown           32  0.000000
# 1       brown          219  0.438356
# 2       brown           77  1.493506
# 3       brown           56  0.035714
# 4       brown           32  0.093750
# ...       ...          ...       ...
# 8758    green          185  0.254054
# 8759    green            4  1.000000
# 8760    green            1  2.000000
# 8761    green          185  0.048649
# 8762    green           10  2.400000
#
# [8763 rows x 7 columns]

# %%
ax = sns.boxplot(
    y="isco_level_1",
    x="quotient",
    hue="Target",
    hue_order=["neutral", "green", "brown"],
    palette=["grey", "lightgreen", "orange"],
    saturation=0.6,
    fliersize=1,
    orient="h",
    data=df_ntrans_long_is_viable_norm
)

ax.set_xlim(0, 5)
ax.set_xlim(0)
plt.legend(loc="lower right")
#ax.set_title("Composition of viable transitions by ISCO-08 1-digit group")
ax.set_xlabel("Number of viable transitions, normalised [-]")
ax.set_ylabel(None)
plt.yticks(np.arange(0,9), list(isco_lvl1_mapping.values()), rotation='horizontal')
plt.tight_layout()
sns.despine()
# Out:
# /Users/felix/Applications/miniconda3/envs/da/lib/python3.8/site-packages/numpy/lib/function_base.py:3968: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
# /Users/felix/Applications/miniconda3/envs/da/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1183: RuntimeWarning: invalid value encountered in double_scalars
#   stats['iqr'] = q3 - q1

# %% [markdown]
# #### Normal plots continue ...

# %%
# desirable
df_ntrans_long_is_desirable = df_ntrans_long.query("Target == 'is_desirable_brown' or Target == 'is_desirable_neutral' or Target == 'is_desirable_green'")
replace_dict = {"Target": {"is_desirable_green": "green", "is_desirable_neutral": "neutral", "is_desirable_brown": "brown"}}

ax = sns.boxplot(
    y="isco_level_1",
    x="value",
    hue="Target",
    hue_order=["neutral", "green", "brown"],
    palette=["grey", "lightgreen", "orange"],
    saturation=0.6,
    fliersize=1,
    orient="h",
    data=df_ntrans_long_is_desirable.replace(replace_dict)
)

ax.set_xlim(0)
plt.legend(loc="lower right")
#ax.set_title("Composition of desirable transitions by ISCO-08 1-digit group")
ax.set_xlabel("Number of desirable transitions [-]")
ax.set_ylabel(None)
plt.yticks(np.arange(0,9), list(isco_lvl1_mapping.values()), rotation='horizontal')
plt.tight_layout()
sns.despine()

# %%
# highly viable
df_ntrans_long_is_highly_viable = df_ntrans_long.query("Target == 'is_highly_viable_brown' or Target == 'is_highly_viable_neutral' or Target == 'is_highly_viable_green'")
replace_dict = {"Target": {"is_highly_viable_green": "green", "is_highly_viable_neutral": "neutral", "is_highly_viable_brown": "brown"}}

ax = sns.boxplot(
    y="isco_level_1",
    x="value",
    hue="Target",
    hue_order=["neutral", "green", "brown"],
    palette=["grey", "lightgreen", "orange"],
    saturation=0.6,
    fliersize=1,
    orient="h",
    data=df_ntrans_long_is_highly_viable.replace(replace_dict)
)

ax.set_xlim(0)
plt.legend(loc="lower right")
#ax.set_title("Composition of highly viable transitions by ISCO-08 1-digit group")
ax.set_xlabel("Number of highly viable transitions [-]")
ax.set_ylabel(None)
plt.yticks(np.arange(0,9), list(isco_lvl1_mapping.values()), rotation='horizontal')
plt.tight_layout()
sns.despine()

# %%
df_ntrans_long_is_highly_desirable = df_ntrans_long.query("Target == 'is_highly_desirable_brown' or Target == 'is_highly_desirable_neutral' or Target == 'is_highly_desirable_green'")
replace_dict = {"Target": {"is_highly_desirable_green": "green", "is_highly_desirable_neutral": "neutral", "is_highly_desirable_brown": "brown"}}

ax = sns.boxplot(
    y="isco_level_1",
    x="value",
    hue="Target",
    hue_order=["neutral", "green", "brown"],
    palette=["grey", "lightgreen", "orange"],
    saturation=0.6,
    fliersize=1,
    orient="h",
    data=df_ntrans_long_is_highly_desirable.replace(replace_dict)
)

ax.set_xlim(0)
plt.legend(loc="lower right")
#ax.set_title("Composition of highly desirable transitions by ISCO-08 1-digit group")
ax.set_xlabel("Number of highly desirable transitions [-]")
ax.set_ylabel(None)
plt.yticks(np.arange(0,9), list(isco_lvl1_mapping.values()), rotation='horizontal')
plt.tight_layout()
sns.despine()

# %% [markdown]
# ## Regression analysis of transition numbers

# %%
# to df
cols_merge = ["preferred_label", "isco_level_1", "annual_earnings", "education_level", "related_work_experience", "on_the_job_training", "job_zone", "is_green", "is_neutral"]
# df_transition_numbers_all = pd.DataFrame.from_dict(transition_numbers_all).transpose()
df_transition_numbers_all_labelled_wide = pd.concat(
    [df_transition_numbers_all, df_metadata[cols_merge]], axis=1
)

df_transition_numbers_all_labelled_wide
# Out:
#       is_viable  is_highly_viable  is_desirable  is_highly_desirable  \
# 0            29                 3            21                    1
# 1           175               128           175                  128
# 2           329                95           328                   95
# 3            82                13            75                   13
# 4           296                28           232                   25
# ...         ...               ...           ...                  ...
# 2916        134                40           122                   36
# 2917         12                 2            11                    2
# 2918         53                16            50                   15
# 2919         81                 3            56                    3
# 2920        152                37           143                   37
#
#       is_viable_brown  is_viable_neutral  is_viable_green  \
# 0                   0                 27                2
# 1                  96                 66               13
# 2                 115                136               78
# 3                   2                 61               19
# 4                   3                206               87
# ...               ...                ...              ...
# 2916                3                 84               47
# 2917                2                  6                4
# 2918                1                 50                2
# 2919                0                 72                9
# 2920               31                 97               24
#
#       is_highly_viable_brown  is_highly_viable_neutral  \
# 0                          0                         3
# 1                         75                        49
# 2                         15                        52
# 3                          0                        13
# 4                          0                        16
# ...                      ...                       ...
# 2916                       1                        27
# 2917                       0                         0
# 2918                       0                        16
# 2919                       0                         3
# 2920                       5                        25
#
#       is_highly_viable_green  is_desirable_brown  is_desirable_neutral  \
# 0                          0                   0                    19
# 1                          4                  96                    66
# 2                         28                 115                   136
# 3                          0                   2                    57
# 4                         12                   3                   145
# ...                      ...                 ...                   ...
# 2916                      12                   3                    75
# 2917                       2                   1                     6
# 2918                       0                   1                    47
# 2919                       0                   0                    47
# 2920                       7                  24                    95
#
#       is_desirable_green  is_highly_desirable_brown  \
# 0                      2                          0
# 1                     13                         75
# 2                     77                         15
# 3                     16                          0
# 4                     84                          0
# ...                  ...                        ...
# 2916                  44                          1
# 2917                   4                          0
# 2918                   2                          0
# 2919                   9                          0
# 2920                  24                          5
#
#       is_highly_desirable_neutral  is_highly_desirable_green  \
# 0                               1                          0
# 1                              49                          4
# 2                              52                         28
# 3                              13                          0
# 4                              15                         10
# ...                           ...                        ...
# 2916                           26                          9
# 2917                            0                          2
# 2918                           15                          0
# 2919                            3                          0
# 2920                           25                          7
#
#                            preferred_label  isco_level_1  annual_earnings  \
# 0                       technical director             2     37555.308176
# 1           metal drawing machine operator             8     22031.963636
# 2               precision device inspector             7     22430.367647
# 3            air traffic safety technician             3     32754.000000
# 4              hospitality revenue manager             2     38839.816377
# ...                                    ...           ...              ...
# 2916                           demographer             2     36135.290249
# 2917                       sorter labourer             9     21357.054545
# 2918                    armoured car guard             5     24315.540984
# 2919  civil service administrative officer             2     33292.986333
# 2920               motor vehicle assembler             8     29879.320665
#
#       education_level  related_work_experience  on_the_job_training  job_zone  \
# 0              6.2477                   8.0309               4.3843       4.0
# 1              2.1163                   2.4383               3.6486       2.0
# 2              2.5397                   4.8863               4.0288       2.0
# 3              4.3848                   5.4808               4.0782       3.0
# 4              6.8261                   6.3481               3.8265       4.0
# ...               ...                      ...                  ...       ...
# 2916           8.3000                   5.5000               4.6000       5.0
# 2917           3.1532                   3.3559               2.8314       2.0
# 2918           2.2215                   3.2642               2.0230       2.0
# 2919           3.9636                   6.9711               3.4248       3.0
# 2920           2.5437                   5.1766               4.4145       2.0
#
#       is_green  is_neutral
# 0        False        True
# 1        False       False
# 2         True       False
# 3        False        True
# 4        False        True
# ...        ...         ...
# 2916     False        True
# 2917      True       False
# 2918     False        True
# 2919     False        True
# 2920     False        True
#
# [2921 rows x 25 columns]

# %%
df_metadata_transitions
# Out:
#         id                                        concept_uri  \
# 0        0  http://data.europa.eu/esco/occupation/00030d09...
# 1        1  http://data.europa.eu/esco/occupation/000e93a3...
# 2        2  http://data.europa.eu/esco/occupation/0019b951...
# 3        3  http://data.europa.eu/esco/occupation/0022f466...
# 4        4  http://data.europa.eu/esco/occupation/002da35b...
# ...    ...                                                ...
# 2916  2937  http://data.europa.eu/esco/occupation/ff656b3a...
# 2917  2938  http://data.europa.eu/esco/occupation/ff8d4065...
# 2918  2939  http://data.europa.eu/esco/occupation/ffa4dd5d...
# 2919  2940  http://data.europa.eu/esco/occupation/ffade2f4...
# 2920  2941  http://data.europa.eu/esco/occupation/ffc292f1...
#
#                            preferred_label  isco_level_4   onet_code  \
# 0                       technical director          2166  27-1011.00
# 1           metal drawing machine operator          8121  51-4021.00
# 2               precision device inspector          7543  51-9061.00
# 3            air traffic safety technician          3155  17-3023.01
# 4              hospitality revenue manager          2431  13-1161.00
# ...                                    ...           ...         ...
# 2916                           demographer          2120  15-2041.00
# 2917                       sorter labourer          9612  51-9199.01
# 2918                    armoured car guard          5414  33-9032.00
# 2919  civil service administrative officer          2422  11-3011.00
# 2920               motor vehicle assembler          8211  51-2031.00
#
#                                         onet_occupation  isco_level_1  \
# 0                                         art directors             2
# 1     extruding and drawing machine setters, operato...             8
# 2     inspectors, testers, sorters, samplers, and we...             7
# 3                   electronics engineering technicians             3
# 4     market research analysts and marketing special...             2
# ...                                                 ...           ...
# 2916                                      statisticians             2
# 2917                  recycling and reclamation workers             9
# 2918                                    security guards             5
# 2919                   administrative services managers             2
# 2920                engine and other machine assemblers             8
#
#       isco_level_2  isco_level_3        occupation_type  n_new_green_tasks  \
# 0               21           216              Non Green                NaN
# 1               81           812              Non Green                NaN
# 2               75           754  Green Enhanced Skills                2.0
# 3               31           315              Non Green                NaN
# 4               24           243              Non Green                NaN
# ...            ...           ...                    ...                ...
# 2916            21           212              Non Green                NaN
# 2917            96           961          New Green N&E               18.0
# 2918            54           541              Non Green                NaN
# 2919            24           242              Non Green                NaN
# 2920            82           821              Non Green                NaN
#
#       n_existing_green_tasks  n_non_green_tasks  greenness_vona_2018  \
# 0                        NaN                NaN                  NaN
# 1                        NaN                NaN                  NaN
# 2                        0.0               30.0             0.066667
# 3                        NaN                NaN                  NaN
# 4                        NaN                NaN                  NaN
# ...                      ...                ...                  ...
# 2916                     NaN                NaN                  NaN
# 2917                     0.0                0.0             1.000000
# 2918                     NaN                NaN                  NaN
# 2919                     NaN                NaN                  NaN
# 2920                     NaN                NaN                  NaN
#
#       greenness_vona_2018_v2  total_paid_hours  annual_earnings  \
# 0                     0.0000         36.670202     37555.308176
# 1                     0.0000         39.904110     22031.963636
# 2                     0.0625         38.709386     22430.367647
# 3                     0.0000         42.036716     32754.000000
# 4                     0.0000         36.354676     38839.816377
# ...                      ...               ...              ...
# 2916                  0.0000         35.494487     36135.290249
# 2917                  1.0000         39.443972     21357.054545
# 2918                  0.0000         37.021429     24315.540984
# 2919                  0.0000         35.240566     33292.986333
# 2920                  0.0000         41.487179     29879.320665
#
#       employment_share  employment_count  job_zone  education_level  \
# 0                  NaN               NaN       4.0           6.2477
# 1             0.000020             645.0       2.0           2.1163
# 2                  NaN               NaN       2.0           2.5397
# 3             0.000087            2797.0       3.0           4.3848
# 4             0.000648           20834.0       4.0           6.8261
# ...                ...               ...       ...              ...
# 2916          0.000286            9184.0       5.0           8.3000
# 2917          0.000417           13414.0       2.0           3.1532
# 2918               NaN               NaN       2.0           2.2215
# 2919          0.001128           36261.0       3.0           3.9636
# 2920          0.000167            5356.0       2.0           2.5437
#
#       related_work_experience  on_the_job_training skill_level_ilo  \
# 0                      8.0309               4.3843               H
# 1                      2.4383               3.6486               M
# 2                      4.8863               4.0288               M
# 3                      5.4808               4.0782               H
# 4                      6.3481               3.8265               H
# ...                       ...                  ...             ...
# 2916                   5.5000               4.6000               H
# 2917                   3.3559               2.8314               L
# 2918                   3.2642               2.0230               M
# 2919                   6.9711               3.4248               H
# 2920                   5.1766               4.4145               M
#
#       new_jobs_absorbing_ilo_2030_es  new_jobs_net_ilo_2030_es  \
# 0                           500000.0                  263000.0
# 1                           339000.0                  712000.0
# 2                            48000.0                  316000.0
# 3                           748000.0                  528000.0
# 4                           218000.0                  147000.0
# ...                              ...                       ...
# 2916                        500000.0                  263000.0
# 2917                        153000.0                  305000.0
# 2918                        141000.0                  179000.0
# 2919                        218000.0                  147000.0
# 2920                         15000.0                  565000.0
#
#       jobs_lost_net_ilo_2030_es  jobs_lost_reallocated_ilo_2030_es  \
# 0                     -253000.0                          -500000.0
# 1                      -34000.0                          -339000.0
# 2                        -500.0                           -48000.0
# 3                     -206000.0                          -748000.0
# 4                      -75000.0                          -218000.0
# ...                         ...                                ...
# 2916                  -253000.0                          -500000.0
# 2917                   -17000.0                          -153000.0
# 2918                   -27000.0                          -141000.0
# 2919                   -75000.0                          -218000.0
# 2920                     -500.0                           -15000.0
#
#       net_change_ilo_2030_es  new_jobs_absorbing_ilo_2030_ce  \
# 0                    10000.0                       1379000.0
# 1                   678000.0                       2913000.0
# 2                   315500.0                       1315000.0
# 3                   322000.0                       3042000.0
# 4                    72000.0                        823000.0
# ...                      ...                             ...
# 2916                 10000.0                       1379000.0
# 2917                288000.0                        860000.0
# 2918                152000.0                        744000.0
# 2919                 72000.0                        823000.0
# 2920                564500.0                        224000.0
#
#       new_jobs_net_ilo_2030_ce  jobs_lost_net_ilo_2030_ce  \
# 0                    1274000.0                  -397000.0
# 1                        500.0                 -5589000.0
# 2                     408000.0                  -440000.0
# 3                    1225000.0                  -965000.0
# 4                     837000.0                   -53000.0
# ...                        ...                        ...
# 2916                 1274000.0                  -397000.0
# 2917                 1152000.0                  -111000.0
# 2918                  579000.0                  -497000.0
# 2919                  837000.0                   -53000.0
# 2920                   14000.0                  -367000.0
#
#       jobs_lost_reallocated_ilo_2030_ce  net_change_ilo_2030_ce  is_brown  \
# 0                            -1379000.0                877000.0     False
# 1                            -2913000.0              -5588500.0      True
# 2                            -1315000.0                -32000.0     False
# 3                            -3042000.0                260000.0     False
# 4                             -823000.0                784000.0     False
# ...                                 ...                     ...       ...
# 2916                         -1379000.0                877000.0     False
# 2917                          -860000.0               1041000.0     False
# 2918                          -744000.0                 82000.0     False
# 2919                          -823000.0                784000.0     False
# 2920                          -224000.0               -353000.0     False
#
#       is_green  is_neutral  is_viable  is_highly_viable  is_desirable  \
# 0        False        True         29                 3            21
# 1        False       False        175               128           175
# 2         True       False        329                95           328
# 3        False        True         82                13            75
# 4        False        True        296                28           232
# ...        ...         ...        ...               ...           ...
# 2916     False        True        134                40           122
# 2917      True       False         12                 2            11
# 2918     False        True         53                16            50
# 2919     False        True         81                 3            56
# 2920     False        True        152                37           143
#
#       is_highly_desirable  is_viable_brown  is_viable_neutral  \
# 0                       1                0                 27
# 1                     128               96                 66
# 2                      95              115                136
# 3                      13                2                 61
# 4                      25                3                206
# ...                   ...              ...                ...
# 2916                   36                3                 84
# 2917                    2                2                  6
# 2918                   15                1                 50
# 2919                    3                0                 72
# 2920                   37               31                 97
#
#       is_viable_green  is_highly_viable_brown  is_highly_viable_neutral  \
# 0                   2                       0                         3
# 1                  13                      75                        49
# 2                  78                      15                        52
# 3                  19                       0                        13
# 4                  87                       0                        16
# ...               ...                     ...                       ...
# 2916               47                       1                        27
# 2917                4                       0                         0
# 2918                2                       0                        16
# 2919                9                       0                         3
# 2920               24                       5                        25
#
#       is_highly_viable_green  is_desirable_brown  is_desirable_neutral  \
# 0                          0                   0                    19
# 1                          4                  96                    66
# 2                         28                 115                   136
# 3                          0                   2                    57
# 4                         12                   3                   145
# ...                      ...                 ...                   ...
# 2916                      12                   3                    75
# 2917                       2                   1                     6
# 2918                       0                   1                    47
# 2919                       0                   0                    47
# 2920                       7                  24                    95
#
#       is_desirable_green  is_highly_desirable_brown  \
# 0                      2                          0
# 1                     13                         75
# 2                     77                         15
# 3                     16                          0
# 4                     84                          0
# ...                  ...                        ...
# 2916                  44                          1
# 2917                   4                          0
# 2918                   2                          0
# 2919                   9                          0
# 2920                  24                          5
#
#       is_highly_desirable_neutral  is_highly_desirable_green
# 0                               1                          0
# 1                              49                          4
# 2                              52                         28
# 3                              13                          0
# 4                              15                         10
# ...                           ...                        ...
# 2916                           26                          9
# 2917                            0                          2
# 2918                           15                          0
# 2919                            3                          0
# 2920                           25                          7
#
# [2921 rows x 53 columns]

# %%
from stargazer.stargazer import Stargazer

df_transition_numbers_all_labelled_wide["is_green_ratio"] = \
    df_transition_numbers_all_labelled_wide["is_viable_green"] / df_transition_numbers_all_labelled_wide["is_viable"]

reg_greenness = ols(
    formula="is_green_ratio ~ annual_earnings + education_level + related_work_experience + on_the_job_training + job_zone + C(isco_level_1)",
    data=df_transition_numbers_all_labelled_wide
).fit(cov_type='HC3')

Stargazer([reg_greenness])
# Out:
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable:is_green_ratio</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td></tr><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">C(isco_level_1)[T.2]</td><td>0.048<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.010)</td></tr><tr><td style="text-align:left">C(isco_level_1)[T.3]</td><td>0.032<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.010)</td></tr><tr><td style="text-align:left">C(isco_level_1)[T.4]</td><td>0.003<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.016)</td></tr><tr><td style="text-align:left">C(isco_level_1)[T.5]</td><td>-0.032<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td>(0.013)</td></tr><tr><td style="text-align:left">C(isco_level_1)[T.6]</td><td>-0.098<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.016)</td></tr><tr><td style="text-align:left">C(isco_level_1)[T.7]</td><td>-0.052<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.011)</td></tr><tr><td style="text-align:left">C(isco_level_1)[T.8]</td><td>-0.044<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.012)</td></tr><tr><td style="text-align:left">C(isco_level_1)[T.9]</td><td>-0.018<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.015)</td></tr><tr><td style="text-align:left">Intercept</td><td>-0.071<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.021)</td></tr><tr><td style="text-align:left">annual_earnings</td><td>0.000<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.000)</td></tr><tr><td style="text-align:left">education_level</td><td>-0.008<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td>(0.003)</td></tr><tr><td style="text-align:left">job_zone</td><td>-0.010<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.007)</td></tr><tr><td style="text-align:left">on_the_job_training</td><td>0.027<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.004)</td></tr><tr><td style="text-align:left">related_work_experience</td><td>0.012<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.003)</td></tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>2,858</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.209</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.206</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>0.139 (df=2844)</td></tr><tr><td style="text-align: left">F Statistic</td><td>79.152<sup>***</sup> (df=13; 2844)</td></tr><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="1" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %%
reg_greenness = ols(
    formula="is_viable ~ annual_earnings + education_level + related_work_experience + on_the_job_training + C(job_zone) + C(isco_level_1) + is_green + is_neutral",
    data=df_transition_numbers_all_labelled_wide
).fit(cov_type='HC3')

Stargazer([reg_greenness])
# Out:
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable:is_viable</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td></tr><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">C(isco_level_1)[T.2]</td><td>-96.631<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(5.957)</td></tr><tr><td style="text-align:left">C(isco_level_1)[T.3]</td><td>-90.141<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(6.946)</td></tr><tr><td style="text-align:left">C(isco_level_1)[T.4]</td><td>-124.726<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(10.660)</td></tr><tr><td style="text-align:left">C(isco_level_1)[T.5]</td><td>-100.699<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(9.130)</td></tr><tr><td style="text-align:left">C(isco_level_1)[T.6]</td><td>-160.437<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(8.038)</td></tr><tr><td style="text-align:left">C(isco_level_1)[T.7]</td><td>-111.838<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(8.270)</td></tr><tr><td style="text-align:left">C(isco_level_1)[T.8]</td><td>-108.113<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(9.150)</td></tr><tr><td style="text-align:left">C(isco_level_1)[T.9]</td><td>-140.088<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(9.905)</td></tr><tr><td style="text-align:left">C(job_zone)[T.2.0]</td><td>30.514<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(5.687)</td></tr><tr><td style="text-align:left">C(job_zone)[T.3.0]</td><td>11.685<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(7.118)</td></tr><tr><td style="text-align:left">C(job_zone)[T.4.0]</td><td>-11.741<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(9.171)</td></tr><tr><td style="text-align:left">C(job_zone)[T.5.0]</td><td>-20.137<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(13.024)</td></tr><tr><td style="text-align:left">Intercept</td><td>131.324<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(14.811)</td></tr><tr><td style="text-align:left">annual_earnings</td><td>0.001<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.000)</td></tr><tr><td style="text-align:left">education_level</td><td>0.211<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(1.717)</td></tr><tr><td style="text-align:left">is_green[T.True]</td><td>33.076<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(6.781)</td></tr><tr><td style="text-align:left">is_neutral[T.True]</td><td>-19.517<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(4.893)</td></tr><tr><td style="text-align:left">on_the_job_training</td><td>-1.123<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(2.065)</td></tr><tr><td style="text-align:left">related_work_experience</td><td>9.794<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(1.265)</td></tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>2,858</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.304</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.300</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>71.429 (df=2839)</td></tr><tr><td style="text-align: left">F Statistic</td><td>79.775<sup>***</sup> (df=18; 2839)</td></tr><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="1" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# #### How do the transition numbers vary between green, neutral and brown occupations?

# %%
# ["brown", "neutral", "green"]
df_metadata_transitions2 = df_metadata_transitions.copy()

df_metadata_transitions2["occ_type"] = df_metadata_transitions2[["is_brown", "is_neutral", "is_green"]].idxmax(axis=1)

# %%
df_metadata_transitions2_long = df_metadata_transitions2.melt(
    id_vars=["occ_type"],
    value_vars=["is_viable", "is_desirable", "is_highly_viable", "is_highly_desirable"],
    value_name="transitions",
    var_name="transition_category"
)

# %%
sns.catplot(
    y="transitions",
    x="occ_type",
    col="transition_category",
    col_wrap=2,
    palette=["grey", "orange", "lightgreen"],
    fliersize=1,
    kind="box",
    data=df_metadata_transitions2_long
)

# %%
sns.catplot(
    y="transitions",
    x="occ_type",
    col="transition_category",
    col_wrap=2,
    palette=["grey", "orange", "lightgreen"],
    fliersize=1,
    kind="violin",
    data=df_metadata_transitions2_long
)

# %%
df_metadata_transitions3_long = df_metadata_transitions2.melt(
    id_vars=["occ_type"],
    value_vars=["annual_earnings", "education_level", "related_work_experience", "on_the_job_training"],
    value_name="value",
    var_name="characteristic"
)

sns.catplot(
    y="value",
    x="occ_type",
    col="characteristic",
    col_wrap=2,
    palette=["grey", "orange", "lightgreen"],
    fliersize=1,
    kind="box",
    sharey=False,
    data=df_metadata_transitions3_long
)

# %%
sns.catplot(
    y="value",
    x="occ_type",
    col="characteristic",
    col_wrap=2,
    palette=["grey", "lightgreen", "orange"],
    fliersize=1,
    kind="violin",
    sharey=False,
    data=df_metadata_transitions3_long
)

# %%
# t-tests for diff in means
from scipy import stats

stats.ttest_ind(
    df_metadata_transitions2.is_desirable_brown,
    df_metadata_transitions2.is_desirable_green
)
# Out:
# Ttest_indResult(statistic=-10.453089054851523, pvalue=2.371430211368237e-25)

# %%
stats.ttest_ind(
    df_metadata_transitions2.is_desirable_brown,
    df_metadata_transitions2.is_desirable_neutral
)
# Out:
# Ttest_indResult(statistic=-48.387147997384595, pvalue=0.0)

# %%
stats.ttest_ind(
    df_metadata_transitions2.is_desirable_green,
    df_metadata_transitions2.is_desirable_neutral
)
# Out:
# Ttest_indResult(statistic=-41.741702932604, pvalue=0.0)

# %% [markdown]
# #### Visualise boxplots in more granular way
# - show transitions from all categories into all categories

# %%
# VIABLE
df_metadata_transitions2_long_v2 = df_metadata_transitions2.melt(
    id_vars=["occ_type"],
    value_vars=["is_viable_neutral", "is_viable_green", "is_viable_brown"],
    value_name="transitions",
    var_name="target"
)

replace_dict = {
    "target": {"is_viable_neutral": "neutral", "is_viable_green": "green", "is_viable_brown": "brown"},
    "occ_type": {"is_neutral": "neutral", "is_green": "green", "is_brown": "brown"}
}

# %%
# boxplot
ax = sns.boxplot(
    x="occ_type",
    y="transitions",
    hue="target",
    palette=["grey", "lightgreen", "orange"],
    fliersize=1,
    data=df_metadata_transitions2_long_v2.replace(replace_dict)
)

ax.set_xlabel("Source")
ax.set_ylabel("Viable transitions [-]")
sns.despine()
plt.tight_layout()

# %%
# barplot
ax = sns.barplot(
    x="occ_type",
    y="transitions",
    hue="target",
    palette=["grey", "lightgreen", "orange"],
    ci="sd",
    capsize=0.05,
    errwidth=1,
    data=df_metadata_transitions2_long_v2.replace(replace_dict)
)

ax.axhline(
    df_metadata_transitions2["is_viable"].mean() / 3,
    linestyle="--",
    color="lightgrey",
    zorder=0
)

ax.set_ylim(0, 175)
ax.set_xlabel("Source")
ax.set_ylabel("Viable transitions [-]")
sns.despine()
plt.tight_layout()

# %%
# DESIRABLE
df_metadata_transitions2_long_v2 = df_metadata_transitions2.melt(
    id_vars=["occ_type"],
    value_vars=["is_desirable_neutral", "is_desirable_green", "is_desirable_brown"],
    value_name="transitions",
    var_name="target"
)

replace_dict = {
    "target": {"is_desirable_neutral": "neutral", "is_desirable_green": "green", "is_desirable_brown": "brown"},
    "occ_type": {"is_neutral": "neutral", "is_green": "green", "is_brown": "brown"}
}

# boxplot
ax = sns.boxplot(
    x="occ_type",
    y="transitions",
    hue="target",
    palette=["grey", "lightgreen", "orange"],
    fliersize=1,
    data=df_metadata_transitions2_long_v2.replace(replace_dict)
)

ax.set_xlabel("Source")
ax.set_ylabel("Desirable transitions [-]")
sns.despine()
plt.tight_layout()

# %%
# barplot
ax = sns.barplot(
    x="occ_type",
    y="transitions",
    hue="target",
    palette=["grey", "lightgreen", "orange"],
    ci="sd",
    capsize=0.05,
    errwidth=1,
    data=df_metadata_transitions2_long_v2.replace(replace_dict)
)

ax.axhline(
    df_metadata_transitions2["is_desirable"].mean() / 3,
    linestyle="--",
    color="lightgrey",
    zorder=0
)

ax.set_ylim(0, 175)
ax.set_xlabel("Source")
ax.set_ylabel("Desirable transitions [-]")
sns.despine()
plt.tight_layout()

# %%
# HIGHLY VIABLE
df_metadata_transitions2_long_v2 = df_metadata_transitions2.melt(
    id_vars=["occ_type"],
    value_vars=["is_highly_viable_neutral", "is_highly_viable_green", "is_highly_viable_brown"],
    value_name="transitions",
    var_name="target"
)

replace_dict = {
    "target": {"is_highly_viable_neutral": "neutral", "is_highly_viable_green": "green", "is_highly_viable_brown": "brown"},
    "occ_type": {"is_neutral": "neutral", "is_green": "green", "is_brown": "brown"}
}

# boxplot
ax = sns.boxplot(
    x="occ_type",
    y="transitions",
    hue="target",
    palette=["grey", "lightgreen", "orange"],
    fliersize=1,
    data=df_metadata_transitions2_long_v2.replace(replace_dict)
)

ax.set_xlabel("Source")
ax.set_ylabel("Highly viable transitions [-]")
sns.despine()
plt.tight_layout()

# %%
# barplot
ax = sns.barplot(
    x="occ_type",
    y="transitions",
    hue="target",
    palette=["grey", "lightgreen", "orange"],
    ci="sd",
    capsize=0.05,
    errwidth=1,
    data=df_metadata_transitions2_long_v2.replace(replace_dict)
)

ax.axhline(
    df_metadata_transitions2["is_highly_viable"].mean() / 3,
    linestyle="--",
    color="lightgrey",
    zorder=0
)

ax.set_ylim(0, 175)
ax.set_xlabel("Source")
ax.set_ylabel("Highly viable transitions [-]")
sns.despine()
plt.tight_layout()

# %%
# HIGHLY DESIRABLE
df_metadata_transitions2_long_v2 = df_metadata_transitions2.melt(
    id_vars=["occ_type"],
    value_vars=["is_highly_desirable_neutral", "is_highly_desirable_green", "is_highly_desirable_brown"],
    value_name="transitions",
    var_name="target"
)

replace_dict = {
    "target": {"is_highly_desirable_neutral": "neutral", "is_highly_desirable_green": "green", "is_highly_desirable_brown": "brown"},
    "occ_type": {"is_neutral": "neutral", "is_green": "green", "is_brown": "brown"}
}

# boxplot
ax = sns.boxplot(
    x="occ_type",
    y="transitions",
    hue="target",
    palette=["grey", "lightgreen", "orange"],
    fliersize=1,
    data=df_metadata_transitions2_long_v2.replace(replace_dict)
)

ax.set_xlabel("Source")
ax.set_ylabel("Highly desirable transitions [-]")
sns.despine()
plt.tight_layout()

# %%
# barplot
ax = sns.barplot(
    x="occ_type",
    y="transitions",
    hue="target",
    palette=["grey", "lightgreen", "orange"],
    ci="sd",
    capsize=0.05,
    errwidth=1,
    data=df_metadata_transitions2_long_v2.replace(replace_dict)
)

ax.axhline(
    df_metadata_transitions2["is_highly_desirable"].mean() / 3,
    linestyle="--",
    color="lightgrey",
    zorder=0
)

ax.set_ylim(0, 175)
ax.set_xlabel("Source")
ax.set_ylabel("Highly desirable transitions [-]")
sns.despine()
plt.tight_layout()

# %% [markdown]
# #### Let's concentrate on the actual research question: the transition possibilities of brown occupations
#
# - don't cover transitions out of neutral or green occupations
# - focus exclusively on transitions out of brown occupations and look at it more granularly

# %%
# store mean values of transition numbers per category
transition_cats = ["is_viable", "is_desirable", "is_highly_viable", "is_highly_desirable"]

transition_cat_means = {}
transition_cat_medians = {}

for cat in transition_cats:
    transition_cat_means[cat] = df_metadata_transitions2[cat].mean()
    transition_cat_medians[cat] = df_metadata_transitions2[cat].median()

# %%
df_metadata_transitions2_brown = df_metadata_transitions2.query("occ_type == 'is_brown'")

# %%
list_of_value_vars = [
    ["is_viable_brown", "is_viable_neutral", "is_viable_green"],
    ["is_highly_viable_brown", "is_highly_viable_neutral", "is_highly_viable_green"],
    ["is_desirable_brown", "is_desirable_neutral", "is_desirable_green"],
    ["is_highly_desirable_brown", "is_highly_desirable_neutral", "is_highly_desirable_green"],
]

list_of_df_categories = []

for i, value_vars in enumerate(list_of_value_vars):
    df_categories = df_metadata_transitions2_brown.melt(
        value_vars=value_vars,
        value_name="transitions",
        var_name="target",
        id_vars="isco_level_1"
    )

    ids = pd.DataFrame(np.column_stack(list(zip(*df_categories.target.str.split("_")))))

    if (i % 2) == 0:
        df_categories["category"] = ids.iloc[:, 1]
        df_categories["target"] = ids.iloc[:, 2]
    else:
        df_categories["category"] = ids.iloc[:, 1] + "_" + ids.iloc[:, 2]
        df_categories["target"] = ids.iloc[:, 3]

    list_of_df_categories.append(df_categories)

df_categories_long = pd.concat(list_of_df_categories).reset_index(drop=True)
df_categories_long["category"] = pd.Categorical(df_categories_long["category"], ["viable", "desirable", "highly_viable", "highly_desirable"])

# %%
# subset by isco code
df_categories_long.groupby(["isco_level_1", "category", "target"]).mean()
# Out:
#                                        transitions
# isco_level_1 category         target
# 1            viable           brown      23.250000
#                               green      31.250000
#                               neutral    71.000000
#              desirable        brown      13.250000
#                               green      21.750000
#                               neutral    49.500000
#              highly_viable    brown      10.000000
#                               green       3.250000
#                               neutral     2.250000
#              highly_desirable brown       7.750000
#                               green       3.250000
#                               neutral     1.000000
# 2            viable           brown      25.000000
#                               green      35.656250
#                               neutral    32.625000
#              desirable        brown      15.406250
#                               green      30.156250
#                               neutral    27.437500
#              highly_viable    brown       6.843750
#                               green       9.656250
#                               neutral     4.500000
#              highly_desirable brown       5.625000
#                               green       9.250000
#                               neutral     3.406250
# 3            viable           brown      42.357143
#                               green      21.964286
#                               neutral    61.107143
#              desirable        brown      40.910714
#                               green      21.678571
#                               neutral    58.821429
#              highly_viable    brown      14.053571
#                               green       2.571429
#                               neutral     9.517857
#              highly_desirable brown      13.714286
#                               green       2.517857
#                               neutral     9.089286
# 4            viable           brown      17.000000
#                               green      20.500000
#                               neutral    24.000000
#              desirable        brown      17.000000
#                               green      20.500000
#                               neutral    24.000000
#              highly_viable    brown       4.500000
#                               green       4.500000
#                               neutral     3.000000
#              highly_desirable brown       4.500000
#                               green       4.500000
#                               neutral     3.000000
# 7            viable           brown      53.857143
#                               green      13.779221
#                               neutral    52.610390
#              desirable        brown      47.454545
#                               green      10.454545
#                               neutral    49.753247
#              highly_viable    brown      23.285714
#                               green       3.181818
#                               neutral    17.025974
#              highly_desirable brown      21.038961
#                               green       2.363636
#                               neutral    16.558442
# 8            viable           brown      74.958904
#                               green       8.817352
#                               neutral    36.876712
#              desirable        brown      73.479452
#                               green       8.744292
#                               neutral    35.520548
#              highly_viable    brown      37.013699
#                               green       1.205479
#                               neutral    13.388128
#              highly_desirable brown      36.621005
#                               green       1.178082
#                               neutral    13.127854
# 9            viable           brown      18.333333
#                               green       8.666667
#                               neutral    27.000000
#              desirable        brown      18.000000
#                               green       8.666667
#                               neutral    26.666667
#              highly_viable    brown       3.000000
#                               green       1.000000
#                               neutral     1.666667
#              highly_desirable brown       3.000000
#                               green       1.000000
#                               neutral     1.666667

# %%
transition_cat_means_num = {
    'is_viable': 100.90345771995892,
    'is_desirable': 87.37247517973297,
    'is_highly_viable': 32.82505991098939,
    'is_highly_desirable': 29.31941116056145
}

delta_mean = df_categories_long.groupby(["category", "target"]).mean().reset_index().set_index("category").join(
    pd.DataFrame(transition_cat_means_num, index=["category"]).T,
    how="left",
)

delta_mean["delta"] = delta_mean.transitions - delta_mean.category / 3
delta_mean["ratio"] = (delta_mean.transitions / (delta_mean.category / 3)) - 1
delta_mean.round(2)
# Out:
#                    target  isco_level_1  transitions  category  delta  ratio
# desirable           brown          6.52        57.69       NaN    NaN    NaN
# desirable           green          6.52        12.86       NaN    NaN    NaN
# desirable         neutral          6.52        40.99       NaN    NaN    NaN
# highly_desirable    brown          6.52        27.07       NaN    NaN    NaN
# highly_desirable    green          6.52         2.30       NaN    NaN    NaN
# highly_desirable  neutral          6.52        12.17       NaN    NaN    NaN
# highly_viable       brown          6.52        27.90       NaN    NaN    NaN
# highly_viable       green          6.52         2.51       NaN    NaN    NaN
# highly_viable     neutral          6.52        12.57       NaN    NaN    NaN
# viable              brown          6.52        60.86       NaN    NaN    NaN
# viable              green          6.52        14.13       NaN    NaN    NaN
# viable            neutral          6.52        43.27       NaN    NaN    NaN

# %%
c = sns.catplot(
    y="transitions",
    x="target",
    col="category",
    #col_wrap=2,
    kind="bar",
    order=["brown", "neutral", "green"],
    palette=["orange", "grey", "lightgreen"],
    ci=95,
    capsize=0.05,
    errwidth=1,
    sharex=False,
    height=5,
    aspect=0.4,
    data=df_categories_long
)

for cat, ax in zip(transition_cats, c.axes[0]):
    ax.set_ylim(0)
    ax.set_xlabel(None)
    ax.set_yticks(np.arange(0, 110, 10))

    ax.axhline(
    transition_cat_means[cat] / 3,
    linestyle="--",
    color="lightgrey",
    zorder=0
)

c.axes[0][0].set_ylabel("Transition number [-]")

plt.tight_layout()


#plt.savefig(
#    os.path.join(figure_dir, "RQ4", "n_transitions_source_brown_only_barplot.png"),
#    dpi=300,
#    bbox_inches="tight"
#)

# %%
c = sns.catplot(
    y="transitions",
    x="target",
    col="category",
    #col_wrap=1,
    kind="box",
    order=["brown", "neutral", "green"],
    palette=["orange", "grey", "lightgreen"],
    sharex=False,
    height=5,
    aspect=0.4,
    fliersize=2,
    data=df_categories_long
)

for cat, ax in zip(transition_cats, c.axes[0]):
    #ax.set_ylim(0)
    ax.set_xlabel(None)

    ax.axhline(
    transition_cat_medians[cat] / 3,
    linestyle="--",
    color="lightgrey",
    zorder=0
)

plt.tight_layout()

#plt.savefig(
#    os.path.join(figure_dir, "RQ4", "n_transitions_source_brown_only_boxplot.png"),
#    dpi=300,
#    bbox_inches="tight"
#)

# %%
df_categories_long.groupby(["category", "target"]).mean()
# Out:
#                           isco_level_1  transitions
# category         target
# viable           brown        6.519084    60.857506
#                  green        6.519084    14.134860
#                  neutral      6.519084    43.272265
# desirable        brown        6.519084    57.687023
#                  green        6.519084    12.857506
#                  neutral      6.519084    40.987277
# highly_viable    brown        6.519084    27.895674
#                  green        6.519084     2.511450
#                  neutral      6.519084    12.569975
# highly_desirable brown        6.519084    27.066158
#                  green        6.519084     2.295165
#                  neutral      6.519084    12.170483

# %% [markdown]
# #### group barplots by isco-08 1-digit level

# %%
new_labels = []
for entry in list(isco_lvl1_mapping.items()):
    code, label = entry
    new_label = str(code) + ": " + label
    new_labels.append(new_label)

new_labels_short = new_labels[0:4] + new_labels[6:9]

# %%
c = sns.catplot(
    y="transitions",
    x="target",
    hue="isco_level_1",
    col="category",
    col_wrap=2,
    kind="bar",
    order=["brown", "neutral", "green"],
    hue_order=new_labels_short,
    palette="Blues_r",
    ci=95,
    capsize=0.05,
    errwidth=1,
    sharex=False,
    height=5,
    aspect=1,
    legend=False,
    data=df_categories_long.query("(isco_level_1 != 5) & (isco_level_1 != 6)").replace({"isco_level_1": dict(zip(np.arange(1, 10), new_labels))})
)

for cat, ax in zip(transition_cats, c.axes):
    ax.set_ylim(0)
    ax.set_xlabel(None)
    ax.set_yticks(np.arange(0, 110, 10))

    ax.axhline(
    transition_cat_means[cat] / 3,
    linestyle="--",
    color="lightgrey",
    zorder=0
)

plt.tight_layout()
plt.legend(loc="best", title="ISCO-08 major groups of source occupations")

# %%
c = sns.catplot(
    y="transitions",
    x="target",
    hue="category",
    col="isco_level_1",
    col_wrap=4,
    kind="bar",
    #order=new_labels[0:4] + new_labels[6:9],
    order=["brown", "neutral", "green"],
    palette="tab20",
    ci=95,
    capsize=0.05,
    errwidth=1,
    sharex=False,
    height=5,
    aspect=0.7,
    legend=False,
    data=df_categories_long.query("(isco_level_1 != 5) & (isco_level_1 != 6)").replace({"isco_level_1": dict(zip(np.arange(1, 10), new_labels))}).sort_values("isco_level_1")
)

for i, ax in enumerate(c.axes):
    ax.set_title(new_labels_short[i])

plt.legend(loc="lower right", bbox_to_anchor=(1.7, 0.4), fontsize=12, title="Transition category")

# %%
for cat, ax in zip(transition_cats, c.axes):
    ax.set_ylim(0)
    ax.set_xlabel(None)
    ax.set_yticks(np.arange(0, 110, 10))

    ax.axhline(
    transition_cat_means[cat] / 3,
    linestyle="--",
    color="lightgrey",
    zorder=0
)

plt.tight_layout()
plt.legend(loc="best", title="ISCO-08 major groups of source occupations")
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
# repeat for green and neutral occs to settle the mean / 3 question
df_metadata_transitions2_green = df_metadata_transitions2.query("occ_type == 'is_green'")

list_of_value_vars = [
    ["is_viable_brown", "is_viable_neutral", "is_viable_green"],
    ["is_highly_viable_brown", "is_highly_viable_neutral", "is_highly_viable_green"],
    ["is_desirable_brown", "is_desirable_neutral", "is_desirable_green"],
    ["is_highly_desirable_brown", "is_highly_desirable_neutral", "is_highly_desirable_green"],
]

list_of_df_categories = []

for i, value_vars in enumerate(list_of_value_vars):
    df_categories = df_metadata_transitions2_green.melt(
        value_vars=value_vars,
        value_name="transitions",
        var_name="target"
    )

    ids = pd.DataFrame(np.column_stack(list(zip(*df_categories.target.str.split("_")))))

    if (i % 2) == 0:
        df_categories["category"] = ids.iloc[:, 1]
        df_categories["target"] = ids.iloc[:, 2]
    else:
        df_categories["category"] = ids.iloc[:, 1] + "_" + ids.iloc[:, 2]
        df_categories["target"] = ids.iloc[:, 3]

    list_of_df_categories.append(df_categories)

df_categories_green_long = pd.concat(list_of_df_categories).reset_index(drop=True)

# %%
c = sns.catplot(
    y="transitions",
    x="target",
    col="category",
    col_wrap=2,
    kind="bar",
    order=["brown", "neutral", "green"],
    palette=["orange", "grey", "lightgreen"],
    ci="sd",
    capsize=0.05,
    errwidth=1,
    sharex=False,
    data=df_categories_green_long
)

for cat, ax in zip(transition_cats, c.axes):
    ax.set_ylim(0)
    ax.set_xlabel(None)
    #ax.set_yticks(np.arange(0, 110, 10))

    ax.axhline(
    transition_cat_means[cat] / 3,
    linestyle="--",
    color="lightgrey",
    zorder=0
)

# %% [markdown]
# #### Create a list of brown occupations with fewest transition options

# %%
df_metadata_transitions2_brown.sort_values("is_desirable").head(30)
# Out:
#         id                                        concept_uri  \
# 1060  1066  http://data.europa.eu/esco/occupation/59207c91...
# 1325  1331  http://data.europa.eu/esco/occupation/6f8f1da1...
# 198    199  http://data.europa.eu/esco/occupation/0fc6c577...
# 1439  1446  http://data.europa.eu/esco/occupation/782ced63...
# 1710  1718  http://data.europa.eu/esco/occupation/8f9b20ff...
# 1751  1759  http://data.europa.eu/esco/occupation/949bccd9...
# 1604  1611  http://data.europa.eu/esco/occupation/86c49d9c...
# 830    834  http://data.europa.eu/esco/occupation/46bbecf4...
# 1113  1119  http://data.europa.eu/esco/occupation/5d549551...
# 1764  1772  http://data.europa.eu/esco/occupation/95a89206...
# 454    456  http://data.europa.eu/esco/occupation/25206eaa...
# 172    173  http://data.europa.eu/esco/occupation/0dae04a4...
# 1799  1807  http://data.europa.eu/esco/occupation/97b3cab1...
# 2872  2892  http://data.europa.eu/esco/occupation/fb6df00f...
# 518    521  http://data.europa.eu/esco/occupation/2b136e51...
# 1531  1538  http://data.europa.eu/esco/occupation/808b5940...
# 1300  1306  http://data.europa.eu/esco/occupation/6da80214...
# 88      88  http://data.europa.eu/esco/occupation/066fe11d...
# 527    530  http://data.europa.eu/esco/occupation/2bdf0696...
# 2113  2123  http://data.europa.eu/esco/occupation/b3cd0522...
# 809    813  http://data.europa.eu/esco/occupation/44b0f118...
# 657    661  http://data.europa.eu/esco/occupation/364e61ab...
# 2471  2488  http://data.europa.eu/esco/occupation/d3c1c718...
# 861    865  http://data.europa.eu/esco/occupation/497a65bf...
# 1008  1013  http://data.europa.eu/esco/occupation/55076d82...
# 290    291  http://data.europa.eu/esco/occupation/183d60f2...
# 2404  2421  http://data.europa.eu/esco/occupation/cd3f5356...
# 625    628  http://data.europa.eu/esco/occupation/3417aab3...
# 1693  1701  http://data.europa.eu/esco/occupation/8d765d88...
# 1740  1748  http://data.europa.eu/esco/occupation/939e05ea...
#
#                          preferred_label  isco_level_4   onet_code  \
# 1060                  firework assembler          8219  47-5031.00
# 1325              recreation model maker          7522  51-7031.00
# 198       sectional belt mould assembler          8141  51-9041.00
# 1439    capsule filling machine operator          8131  51-9111.00
# 1710  automated cable vehicle controller          8343  53-7041.00
# 1751              wicker furniture maker          7317  51-7021.00
# 1604                          roustabout          8113  47-5071.00
# 830                          well-digger          8113  47-5021.00
# 1113                         tool pusher          8113  47-5013.00
# 1764                         upholsterer          7534  51-6093.00
# 454             casting machine operator          8121  51-4052.00
# 172          granulator machine operator          8131  51-9011.00
# 1799              gas service technician          7126  51-8092.00
# 2872                  furniture finisher          7522  51-7021.00
# 518             textile machine operator          8152  51-6063.00
# 1531                             assayer          2146  19-4031.00
# 1300           knitting machine operator          8152  51-6063.00
# 88                             enameller          8122  51-9121.00
# 527                         meter reader          9623  43-5041.00
# 2113                       carpet weaver          7318  51-6063.00
# 809            wood drying kiln operator          7521  51-9051.00
# 657                              driller          8111  47-5021.00
# 2471                   oil rig motorhand          8113  47-5012.00
# 861                           oenologist          2145  17-2041.00
# 1008                     textile chemist          2113  19-2031.00
# 290                 ammunition assembler          8219  47-5031.00
# 2404               furniture upholsterer          7534  51-6093.00
# 625                     tufting operator          8152  51-6063.00
# 1693                           roughneck          8113  47-5071.00
# 1740            weaving machine operator          8152  51-6063.00
#
#                                         onet_occupation  isco_level_1  \
# 1060  explosives workers, ordnance handling experts,...             8
# 1325                                 model makers, wood             7
# 198   extruding, forming, pressing, and compacting m...             8
# 1439  packaging and filling machine operators and te...             8
# 1710                          hoist and winch operators             8
# 1751                                furniture finishers             7
# 1604                           roustabouts, oil and gas             8
# 830                  earth drillers, except oil and gas             8
# 1113       service unit operators, oil, gas, and mining             8
# 1764                                       upholsterers             7
# 454                          pourers and casters, metal             8
# 172            chemical equipment operators and tenders             8
# 1799                                gas plant operators             7
# 2872                                furniture finishers             7
# 518   textile knitting and weaving machine setters, ...             8
# 1531                               chemical technicians             2
# 1300  textile knitting and weaving machine setters, ...             8
# 88    coating, painting, and spraying machine setter...             8
# 527                            meter readers, utilities             9
# 2113  textile knitting and weaving machine setters, ...             7
# 809   furnace, kiln, oven, drier, and kettle operato...             7
# 657                  earth drillers, except oil and gas             8
# 2471                rotary drill operators, oil and gas             8
# 861                                  chemical engineers             2
# 1008                                           chemists             2
# 290   explosives workers, ordnance handling experts,...             8
# 2404                                       upholsterers             7
# 625   textile knitting and weaving machine setters, ...             8
# 1693                           roustabouts, oil and gas             8
# 1740  textile knitting and weaving machine setters, ...             8
#
#       isco_level_2  isco_level_3        occupation_type  n_new_green_tasks  \
# 1060            82           821              Non Green                NaN
# 1325            75           752              Non Green                NaN
# 198             81           814              Non Green                NaN
# 1439            81           813              Non Green                NaN
# 1710            83           834              Non Green                NaN
# 1751            73           731              Non Green                NaN
# 1604            81           811              Non Green                NaN
# 830             81           811              Non Green                NaN
# 1113            81           811  Green Enhanced Skills                1.0
# 1764            75           753              Non Green                NaN
# 454             81           812              Non Green                NaN
# 172             81           813              Non Green                NaN
# 1799            71           712              Non Green                NaN
# 2872            75           752              Non Green                NaN
# 518             81           815              Non Green                NaN
# 1531            21           214              Non Green                NaN
# 1300            81           815              Non Green                NaN
# 88              81           812              Non Green                NaN
# 527             96           962              Non Green                NaN
# 2113            73           731              Non Green                NaN
# 809             75           752              Non Green                NaN
# 657             81           811              Non Green                NaN
# 2471            81           811              Non Green                NaN
# 861             21           214              Non Green                NaN
# 1008            21           211              Non Green                NaN
# 290             82           821              Non Green                NaN
# 2404            75           753              Non Green                NaN
# 625             81           815              Non Green                NaN
# 1693            81           811              Non Green                NaN
# 1740            81           815              Non Green                NaN
#
#       n_existing_green_tasks  n_non_green_tasks  greenness_vona_2018  \
# 1060                     NaN                NaN                  NaN
# 1325                     NaN                NaN                  NaN
# 198                      NaN                NaN                  NaN
# 1439                     NaN                NaN                  NaN
# 1710                     NaN                NaN                  NaN
# 1751                     NaN                NaN                  NaN
# 1604                     NaN                NaN                  NaN
# 830                      NaN                NaN                  NaN
# 1113                     0.0               18.0             0.055556
# 1764                     NaN                NaN                  NaN
# 454                      NaN                NaN                  NaN
# 172                      NaN                NaN                  NaN
# 1799                     NaN                NaN                  NaN
# 2872                     NaN                NaN                  NaN
# 518                      NaN                NaN                  NaN
# 1531                     NaN                NaN                  NaN
# 1300                     NaN                NaN                  NaN
# 88                       NaN                NaN                  NaN
# 527                      NaN                NaN                  NaN
# 2113                     NaN                NaN                  NaN
# 809                      NaN                NaN                  NaN
# 657                      NaN                NaN                  NaN
# 2471                     NaN                NaN                  NaN
# 861                      NaN                NaN                  NaN
# 1008                     NaN                NaN                  NaN
# 290                      NaN                NaN                  NaN
# 2404                     NaN                NaN                  NaN
# 625                      NaN                NaN                  NaN
# 1693                     NaN                NaN                  NaN
# 1740                     NaN                NaN                  NaN
#
#       greenness_vona_2018_v2  total_paid_hours  annual_earnings  \
# 1060                0.000000         41.395976     29810.139535
# 1325                0.000000         40.378983     24701.996269
# 198                 0.000000         39.918182     24469.800000
# 1439                0.000000         39.965625     22211.820144
# 1710                0.000000         38.918305     23801.455000
# 1751                0.000000         38.835000     23833.750000
# 1604                0.000000         38.261947     26037.989011
# 830                 0.000000         38.261947     26037.989011
# 1113                0.052632         38.261947     26037.989011
# 1764                0.000000         38.133333     26121.000000
# 454                 0.000000         39.904110     22031.963636
# 172                 0.000000         39.965625     22211.820144
# 1799                0.000000         41.114286     30837.176606
# 2872                0.000000         40.378983     24701.996269
# 518                 0.000000         41.531383     31169.327160
# 1531                0.000000         40.178069     36554.033333
# 1300                0.000000         41.531383     31169.327160
# 88                  0.000000         39.965132     22295.400000
# 527                 0.000000         35.900000     19039.000000
# 2113                0.000000         37.803488     21611.487805
# 809                 0.000000         41.028571     22772.272727
# 657                 0.000000         41.125041     28282.005769
# 2471                0.000000         38.261947     26037.989011
# 861                 0.000000         40.040954     35709.341373
# 1008                0.000000         34.707692     36778.830769
# 290                 0.000000         41.395976     29810.139535
# 2404                0.000000         38.133333     26121.000000
# 625                 0.000000         41.531383     31169.327160
# 1693                0.000000         38.261947     26037.989011
# 1740                0.000000         41.531383     31169.327160
#
#       employment_share  employment_count  job_zone  education_level  \
# 1060          0.000167            5356.0       2.0           2.4583
# 1325          0.000127            4088.0       3.0           2.2477
# 198                NaN               NaN       2.0           2.5608
# 1439          0.000053            1699.0       2.0           1.9021
# 1710          0.000272            8741.0       2.0           2.1391
# 1751          0.000064            2046.0       2.0           1.6771
# 1604          0.000021             680.0       1.0           1.7165
# 830           0.000021             680.0       2.0           1.9706
# 1113          0.000021             680.0       2.0           1.6300
# 1764          0.000054            1748.0       2.0           1.5618
# 454           0.000020             645.0       2.0           1.7683
# 172           0.000053            1699.0       2.0           3.0056
# 1799          0.000540           17350.0       3.0           2.6227
# 2872          0.000127            4088.0       2.0           1.6771
# 518           0.000059            1883.0       2.0           2.0230
# 1531          0.000359           11552.0       3.0           4.5735
# 1300          0.000059            1883.0       2.0           2.0230
# 88            0.000020             645.0       2.0           1.7289
# 527           0.000899           28911.0       2.0           2.7088
# 2113          0.000064            2046.0       2.0           2.0230
# 809           0.000127            4088.0       2.0           2.1256
# 657           0.000021             680.0       2.0           1.9706
# 2471          0.000021             680.0       2.0           2.5789
# 861                NaN               NaN       4.0           6.6363
# 1008               NaN               NaN       4.0           6.1569
# 290           0.000167            5356.0       2.0           2.4583
# 2404               NaN               NaN       2.0           1.5618
# 625                NaN               NaN       2.0           2.0230
# 1693          0.000021             680.0       1.0           1.7165
# 1740          0.000059            1883.0       2.0           2.0230
#
#       related_work_experience  on_the_job_training skill_level_ilo  \
# 1060                   5.7500               5.0831               M
# 1325                   5.7608               4.9825               M
# 198                    4.7591               3.8960               M
# 1439                   3.7702               2.6640               M
# 1710                   5.9754               4.9077               M
# 1751                   5.5099               4.2003               M
# 1604                   2.7936               2.9478               M
# 830                    4.5053               4.2808               M
# 1113                   4.9407               3.9111               M
# 1764                   5.3552               3.5922               M
# 454                    3.3988               2.9990               M
# 172                    5.9065               4.8177               M
# 1799                   4.7900               4.5794               M
# 2872                   5.5099               4.2003               M
# 518                    2.9116               3.2023               M
# 1531                   4.4165               3.6283               H
# 1300                   2.9116               3.2023               M
# 88                     2.4444               2.7162               M
# 527                    3.5885               3.4576               L
# 2113                   2.9116               3.2023               M
# 809                    3.8709               3.6751               M
# 657                    4.5053               4.2808               M
# 2471                   6.0571               5.0410               M
# 861                    4.3646               3.5456               H
# 1008                   4.9841               4.1828               H
# 290                    5.7500               5.0831               M
# 2404                   5.3552               3.5922               M
# 625                    2.9116               3.2023               M
# 1693                   2.7936               2.9478               M
# 1740                   2.9116               3.2023               M
#
#       new_jobs_absorbing_ilo_2030_es  new_jobs_net_ilo_2030_es  \
# 1060                         15000.0                  565000.0
# 1325                         48000.0                  316000.0
# 198                         339000.0                  712000.0
# 1439                        339000.0                  712000.0
# 1710                        329000.0                  810000.0
# 1751                         27000.0                  310000.0
# 1604                        339000.0                  712000.0
# 830                         339000.0                  712000.0
# 1113                        339000.0                  712000.0
# 1764                         48000.0                  316000.0
# 454                         339000.0                  712000.0
# 172                         339000.0                  712000.0
# 1799                        102000.0                 3733000.0
# 2872                         48000.0                  316000.0
# 518                         339000.0                  712000.0
# 1531                        500000.0                  263000.0
# 1300                        339000.0                  712000.0
# 88                          339000.0                  712000.0
# 527                         153000.0                  305000.0
# 2113                         27000.0                  310000.0
# 809                          48000.0                  316000.0
# 657                         339000.0                  712000.0
# 2471                        339000.0                  712000.0
# 861                         500000.0                  263000.0
# 1008                        500000.0                  263000.0
# 290                          15000.0                  565000.0
# 2404                         48000.0                  316000.0
# 625                         339000.0                  712000.0
# 1693                        339000.0                  712000.0
# 1740                        339000.0                  712000.0
#
#       jobs_lost_net_ilo_2030_es  jobs_lost_reallocated_ilo_2030_es  \
# 1060                     -500.0                           -15000.0
# 1325                     -500.0                           -48000.0
# 198                    -34000.0                          -339000.0
# 1439                   -34000.0                          -339000.0
# 1710                   -33000.0                          -329000.0
# 1751                     -500.0                           -27000.0
# 1604                   -34000.0                          -339000.0
# 830                    -34000.0                          -339000.0
# 1113                   -34000.0                          -339000.0
# 1764                     -500.0                           -48000.0
# 454                    -34000.0                          -339000.0
# 172                    -34000.0                          -339000.0
# 1799                     -500.0                          -102000.0
# 2872                     -500.0                           -48000.0
# 518                    -34000.0                          -339000.0
# 1531                  -253000.0                          -500000.0
# 1300                   -34000.0                          -339000.0
# 88                     -34000.0                          -339000.0
# 527                    -17000.0                          -153000.0
# 2113                     -500.0                           -27000.0
# 809                      -500.0                           -48000.0
# 657                    -34000.0                          -339000.0
# 2471                   -34000.0                          -339000.0
# 861                   -253000.0                          -500000.0
# 1008                  -253000.0                          -500000.0
# 290                      -500.0                           -15000.0
# 2404                     -500.0                           -48000.0
# 625                    -34000.0                          -339000.0
# 1693                   -34000.0                          -339000.0
# 1740                   -34000.0                          -339000.0
#
#       net_change_ilo_2030_es  new_jobs_absorbing_ilo_2030_ce  \
# 1060                564500.0                        224000.0
# 1325                315500.0                       1315000.0
# 198                 678000.0                       2913000.0
# 1439                678000.0                       2913000.0
# 1710                777000.0                       2899000.0
# 1751                309500.0                       1331000.0
# 1604                678000.0                       2913000.0
# 830                 678000.0                       2913000.0
# 1113                678000.0                       2913000.0
# 1764                315500.0                       1315000.0
# 454                 678000.0                       2913000.0
# 172                 678000.0                       2913000.0
# 1799               3732500.0                       2579000.0
# 2872                315500.0                       1315000.0
# 518                 678000.0                       2913000.0
# 1531                 10000.0                       1379000.0
# 1300                678000.0                       2913000.0
# 88                  678000.0                       2913000.0
# 527                 288000.0                        860000.0
# 2113                309500.0                       1331000.0
# 809                 315500.0                       1315000.0
# 657                 678000.0                       2913000.0
# 2471                678000.0                       2913000.0
# 861                  10000.0                       1379000.0
# 1008                 10000.0                       1379000.0
# 290                 564500.0                        224000.0
# 2404                315500.0                       1315000.0
# 625                 678000.0                       2913000.0
# 1693                678000.0                       2913000.0
# 1740                678000.0                       2913000.0
#
#       new_jobs_net_ilo_2030_ce  jobs_lost_net_ilo_2030_ce  \
# 1060                   14000.0                  -367000.0
# 1325                  408000.0                  -440000.0
# 198                      500.0                 -5589000.0
# 1439                     500.0                 -5589000.0
# 1710                  753000.0                 -2612000.0
# 1751                   35000.0                 -1057000.0
# 1604                     500.0                 -5589000.0
# 830                      500.0                 -5589000.0
# 1113                     500.0                 -5589000.0
# 1764                  408000.0                  -440000.0
# 454                      500.0                 -5589000.0
# 172                      500.0                 -5589000.0
# 1799                  150000.0                 -2172000.0
# 2872                  408000.0                  -440000.0
# 518                      500.0                 -5589000.0
# 1531                 1274000.0                  -397000.0
# 1300                     500.0                 -5589000.0
# 88                       500.0                 -5589000.0
# 527                  1152000.0                  -111000.0
# 2113                   35000.0                 -1057000.0
# 809                   408000.0                  -440000.0
# 657                      500.0                 -5589000.0
# 2471                     500.0                 -5589000.0
# 861                  1274000.0                  -397000.0
# 1008                 1274000.0                  -397000.0
# 290                    14000.0                  -367000.0
# 2404                  408000.0                  -440000.0
# 625                      500.0                 -5589000.0
# 1693                     500.0                 -5589000.0
# 1740                     500.0                 -5589000.0
#
#       jobs_lost_reallocated_ilo_2030_ce  net_change_ilo_2030_ce  is_brown  \
# 1060                          -224000.0               -353000.0      True
# 1325                         -1315000.0                -32000.0      True
# 198                          -2913000.0              -5588500.0      True
# 1439                         -2913000.0              -5588500.0      True
# 1710                         -2899000.0              -1859000.0      True
# 1751                         -1331000.0              -1022000.0      True
# 1604                         -2913000.0              -5588500.0      True
# 830                          -2913000.0              -5588500.0      True
# 1113                         -2913000.0              -5588500.0      True
# 1764                         -1315000.0                -32000.0      True
# 454                          -2913000.0              -5588500.0      True
# 172                          -2913000.0              -5588500.0      True
# 1799                         -2579000.0              -2022000.0      True
# 2872                         -1315000.0                -32000.0      True
# 518                          -2913000.0              -5588500.0      True
# 1531                         -1379000.0                877000.0      True
# 1300                         -2913000.0              -5588500.0      True
# 88                           -2913000.0              -5588500.0      True
# 527                           -860000.0               1041000.0      True
# 2113                         -1331000.0              -1022000.0      True
# 809                          -1315000.0                -32000.0      True
# 657                          -2913000.0              -5588500.0      True
# 2471                         -2913000.0              -5588500.0      True
# 861                          -1379000.0                877000.0      True
# 1008                         -1379000.0                877000.0      True
# 290                           -224000.0               -353000.0      True
# 2404                         -1315000.0                -32000.0      True
# 625                          -2913000.0              -5588500.0      True
# 1693                         -2913000.0              -5588500.0      True
# 1740                         -2913000.0              -5588500.0      True
#
#       is_green  is_neutral  is_viable  is_highly_viable  is_desirable  \
# 1060     False       False          2                 0             1
# 1325     False       False          5                 2             5
# 198      False       False          6                 0             6
# 1439     False       False         11                 0            11
# 1710     False       False         12                 0            11
# 1751     False       False         11                 4            11
# 1604     False       False         13                 1            13
# 830      False       False         13                 1            13
# 1113     False       False         14                 1            14
# 1764     False       False         21                 7            15
# 454      False       False         16                 3            16
# 172      False       False         16                 0            16
# 1799     False       False         30                 9            17
# 2872     False       False         18                 8            17
# 518      False       False         37                18            17
# 1531     False       False         38                 8            17
# 1300     False       False         38                21            18
# 88       False       False         18                 3            18
# 527      False       False         19                 0            19
# 2113     False       False         20                 8            20
# 809      False       False         20                 3            20
# 657      False       False         20                 0            20
# 2471     False       False         21                 2            21
# 861      False       False         82                 6            22
# 1008     False       False         44                13            22
# 290      False       False         25                 0            22
# 2404     False       False         31                 7            23
# 625      False       False         49                19            23
# 1693     False       False         23                 2            23
# 1740     False       False         49                30            25
#
#       is_highly_desirable  is_viable_brown  is_viable_neutral  \
# 1060                    0                2                  0
# 1325                    2                1                  3
# 198                     0                6                  0
# 1439                    0                9                  2
# 1710                    0                0                 11
# 1751                    4                7                  4
# 1604                    1                5                  8
# 830                     1                7                  5
# 1113                    1                5                  9
# 1764                    7                9                 12
# 454                     3                3                 11
# 172                     0               14                  2
# 1799                    4               13                  8
# 2872                    8                9                  9
# 518                    10               25                 10
# 1531                    2               14                 18
# 1300                   12               25                 10
# 88                      3               15                  2
# 527                     0                0                 14
# 2113                    8               19                  1
# 809                     3               19                  0
# 657                     0               14                  3
# 2471                    2                8                 13
# 861                     4               65                 15
# 1008                    3               19                 13
# 290                     0               13                 11
# 2404                    7               13                 18
# 625                     8               21                 20
# 1693                    2                8                 12
# 1740                   17               27                 14
#
#       is_viable_green  is_highly_viable_brown  is_highly_viable_neutral  \
# 1060                0                       0                         0
# 1325                1                       0                         2
# 198                 0                       0                         0
# 1439                0                       0                         0
# 1710                1                       0                         0
# 1751                0                       3                         1
# 1604                0                       1                         0
# 830                 1                       1                         0
# 1113                0                       1                         0
# 1764                0                       7                         0
# 454                 2                       0                         3
# 172                 0                       0                         0
# 1799                9                       5                         1
# 2872                0                       6                         2
# 518                 2                      16                         1
# 1531                6                       6                         2
# 1300                3                      18                         2
# 88                  1                       3                         0
# 527                 5                       0                         0
# 2113                0                       8                         0
# 809                 1                       3                         0
# 657                 3                       0                         0
# 2471                0                       1                         1
# 861                 2                       6                         0
# 1008               12                       3                         4
# 290                 1                       0                         0
# 2404                0                       7                         0
# 625                 8                      13                         5
# 1693                3                       2                         0
# 1740                8                      23                         4
#
#       is_highly_viable_green  is_desirable_brown  is_desirable_neutral  \
# 1060                       0                   1                     0
# 1325                       0                   1                     3
# 198                        0                   6                     0
# 1439                       0                   9                     2
# 1710                       0                   0                    10
# 1751                       0                   7                     4
# 1604                       0                   5                     8
# 830                        0                   7                     5
# 1113                       0                   5                     9
# 1764                       0                   9                     6
# 454                        0                   3                    11
# 172                        0                  14                     2
# 1799                       3                   5                     7
# 2872                       0                   9                     8
# 518                        1                  14                     1
# 1531                       0                   9                     7
# 1300                       1                  14                     2
# 88                         0                  15                     2
# 527                        0                   0                    14
# 2113                       0                  19                     1
# 809                        0                  19                     0
# 657                        0                  14                     3
# 2471                       0                   8                    13
# 861                        0                  15                     6
# 1008                       6                  11                     5
# 290                        0                  10                    11
# 2404                       0                  13                    10
# 625                        1                  14                     3
# 1693                       0                   8                    12
# 1740                       3                  16                     3
#
#       is_desirable_green  is_highly_desirable_brown  \
# 1060                   0                          0
# 1325                   1                          0
# 198                    0                          0
# 1439                   0                          0
# 1710                   1                          0
# 1751                   0                          3
# 1604                   0                          1
# 830                    1                          1
# 1113                   0                          1
# 1764                   0                          7
# 454                    2                          0
# 172                    0                          0
# 1799                   5                          1
# 2872                   0                          6
# 518                    2                          9
# 1531                   1                          2
# 1300                   2                         11
# 88                     1                          3
# 527                    5                          0
# 2113                   0                          8
# 809                    1                          3
# 657                    3                          0
# 2471                   0                          1
# 861                    1                          4
# 1008                   6                          0
# 290                    1                          0
# 2404                   0                          7
# 625                    6                          7
# 1693                   3                          2
# 1740                   6                         14
#
#       is_highly_desirable_neutral  is_highly_desirable_green  occ_type
# 1060                            0                          0  is_brown
# 1325                            2                          0  is_brown
# 198                             0                          0  is_brown
# 1439                            0                          0  is_brown
# 1710                            0                          0  is_brown
# 1751                            1                          0  is_brown
# 1604                            0                          0  is_brown
# 830                             0                          0  is_brown
# 1113                            0                          0  is_brown
# 1764                            0                          0  is_brown
# 454                             3                          0  is_brown
# 172                             0                          0  is_brown
# 1799                            0                          3  is_brown
# 2872                            2                          0  is_brown
# 518                             0                          1  is_brown
# 1531                            0                          0  is_brown
# 1300                            0                          1  is_brown
# 88                              0                          0  is_brown
# 527                             0                          0  is_brown
# 2113                            0                          0  is_brown
# 809                             0                          0  is_brown
# 657                             0                          0  is_brown
# 2471                            1                          0  is_brown
# 861                             0                          0  is_brown
# 1008                            1                          2  is_brown
# 290                             0                          0  is_brown
# 2404                            0                          0  is_brown
# 625                             0                          1  is_brown
# 1693                            0                          0  is_brown
# 1740                            1                          2  is_brown

# %% [markdown]
# #### Job zone statistics by occ type

# %%
df_metadata_transitions2[["occ_type", "job_zone"]].groupby("occ_type").aggregate(["median", "mean", "std"])
# Out:
#            job_zone
#              median      mean       std
# occ_type
# is_brown        2.0  2.251908  0.662519
# is_green        4.0  3.525000  0.784802
# is_neutral      3.0  3.210450  1.084399

# %%
test = df_metadata_transitions2.copy()
test["count"] = 1
test[["occ_type", "job_zone", "count"]].groupby(["job_zone", "occ_type"]).count()
# Out:
#                      count
# job_zone occ_type
# 1.0      is_brown        8
#          is_neutral     62
# 2.0      is_brown      319
#          is_green       61
#          is_neutral    579
# 3.0      is_brown       25
#          is_green       80
#          is_neutral    566
# 4.0      is_brown       41
#          is_green      247
#          is_neutral    582
# 5.0      is_green       12
#          is_neutral    278

# %%
#sns.set_style("ticks", {'axes.grid': True, "grid.linestyle": "--"})

fig, ax = plt.subplots(figsize=(6, 2.5))

sns.histplot(
    x="job_zone",
    hue="occ_type",
    multiple="dodge",
    stat="count",
    hue_order=["brown", "neutral", "green"],
    palette=["orange", "grey", "lightgreen"],
    data=df_metadata_transitions2.replace(replace_dict["occ_type"]),
    ax=ax
)

ax.xaxis.grid()
ax.set_xlabel("Job zone")
ax.set_xticks(np.arange(1, 6))
#ax.set_yticks(np.arange(100, 700, 100))
sns.despine()
